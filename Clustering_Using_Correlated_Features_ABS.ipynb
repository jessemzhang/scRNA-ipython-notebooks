# %% [markdown]
# This iPython notebook looks at the absolute value of the correlation matrix between all genes. I hope to answer the question: By looking at the most cohesize biclusters (highest mean correlations not including the diagonals), can we get genes that are biologically relevant?

# %%
# Load data
import numpy as np

X = np.loadtxt('/data/jessez/Gene_count_datasets/Datasets/batch_all/X');
genes = np.loadtxt('/data/jessez/Gene_count_datasets/Genes/genes.txt',dtype=str)
genes_d1 = ['Isl1','Drd1','Sfxn1','Nrxn1']
genes_d2 = ['Drd2','Penk','Sp9','Gpr52','Gpr88']
batches = np.loadtxt('/data/jessez/Gene_count_datasets/Batch_nums/batch_num_all.txt')
M,N = np.shape(X)

# %%
# Functions for performing clustering with correlated features

from sklearn.cluster.bicluster import SpectralCoclustering
import matplotlib.pyplot as plt

# Bicluster matrix R into k clusters
def jz_bicluster(R,k):
    model = SpectralCoclustering(n_clusters=k, random_state=0)
    model.fit(R)
    return model.row_labels_

# Plot biclusters:
def plot_biclusters(R,labels):
    fit_data = R[np.argsort(labels)]
    fit_data = fit_data[:, np.argsort(labels)]
    plt.matshow(fit_data, cmap=plt.cm.Blues)
    plt.title("After biclustering; rearranged to show biclusters")
    plt.show()

# Score each cluster based on how high its correlations (values) are
def clust_score(c,R,labels):
    # number of each label
    n = float(np.sum(labels == c))
    # Sum up correlations (ignore entries along the diagonal)
    s = np.sum(R[labels == c,:][:,labels == c])-n
    # Score is normalized to be from 0 (worst score) to 1 (best score)
    return s/(n**2-n)

# For a symmetric NxN matrix R and a length-N vector of labels (for each row/col in R),
# find score each cluster
def test_all_clust_scores(R,labels):
    max_label = np.max(labels)+1
    save_score = np.zeros(max_label)
    for i in range(max_label):
        save_score[i] = clust_score(i,R,labels)
    return np.nan_to_num(save_score)

# Look at top N best sep scores and the clusters that produced them    
def check_top_sep_scores(save_score,N):
    # Sort rows by second column (clust scores)
    a = np.transpose([np.argsort(save_score)+1, np.sort(save_score)])
    if N <= np.size(save_score):
        return np.flipud(a[-N:])
    else:
        return np.flipud(a)
    
# Check to see which clusters d1d2 genes end up in 
def check_d1d2_genes_labels(labels,gene_names):
    # see if d1d2 genes are clustered into the same group
    for gene in ['Isl1','Drd1','Sfxn1','Nrxn1','Drd2','Penk','Sp9','Gpr52','Gpr88']:
        print gene + ' is in cluster ' + str(labels[np.where(gene_names == gene)])
    print ' '

# Save genes in two desired clusters
def save_genes_in_two_clusts(c1,c2,gene_names,filename):
    save_genes = np.zeros(np.size(gene_names))
    for i in range(np.size(gene_names)):
        if labels[i] == c1 or labels[i] == c2:
            save_genes[i] = 1
    np.savetxt(filename,gene_names[np.where(save_genes)],delimiter='\t',fmt="%s")

# %%
# Test for R_abs over all batches
R_abs = np.abs(np.corrcoef(np.transpose(X)))

# Test various values of k, and see how well they do at selecting out biclusters that correspond to d1 and d2
# %matplotlib inline
for k in [5,10,20,50,100,200,500,1000,2000]:
    print 'Testing for k equals ' + str(k) + '...'
    labels = jz_bicluster(R_abs,k)
    plot_biclusters(R_abs,labels)
    clust_scores = test_all_clust_scores(R_abs,labels)
    print check_top_sep_scores(clust_scores,20)
    check_d1d2_genes_labels(labels,genes)
# Out:
# Testing for k equals 5...
# [[ 3.          0.20240185]
#  [ 5.          0.19545182]
#  [ 4.          0.11098139]
#  [ 1.          0.09113542]
#  [ 2.          0.05762673]]
# Isl1 is in cluster [0]
# Drd1 is in cluster [0]
# Sfxn1 is in cluster [0]
# Nrxn1 is in cluster [0]
# Drd2 is in cluster [3]
# Penk is in cluster [3]
# Sp9 is in cluster [1]
# Gpr52 is in cluster [3]
# Gpr88 is in cluster [3]
#
# Testing for k equals 10...
# [[ 10.           0.26790951]
#  [  6.           0.24398001]
#  [  8.           0.16505732]
#  [  9.           0.13984651]
#  [  1.           0.13335901]
#  [  4.           0.1004825 ]
#  [  2.           0.09117491]
#  [  7.           0.07954424]
#  [  3.           0.07684086]
#  [  5.           0.05567928]]
# Isl1 is in cluster [3]
# Drd1 is in cluster [3]
# Sfxn1 is in cluster [3]
# Nrxn1 is in cluster [7]
# Drd2 is in cluster [8]
# Penk is in cluster [8]
# Sp9 is in cluster [4]
# Gpr52 is in cluster [8]
# Gpr88 is in cluster [8]
#
# Testing for k equals 20...
# [[  7.           0.33589945]
#  [  1.           0.28782028]
#  [ 20.           0.21466437]
#  [  4.           0.20776355]
#  [ 19.           0.18399303]
#  [ 13.           0.1566436 ]
#  [ 14.           0.15139138]
#  [ 10.           0.14097802]
#  [  3.           0.13359859]
#  [ 11.           0.12181061]
#  [  6.           0.10971253]
#  [  9.           0.1042651 ]
#  [ 18.           0.09825972]
#  [  2.           0.09088348]
#  [ 15.           0.08253641]
#  [  5.           0.07670379]
#  [ 17.           0.07519463]
#  [ 16.           0.06066446]
#  [ 12.           0.05897798]
#  [  8.           0.05150327]]
# Isl1 is in cluster [8]
# Drd1 is in cluster [8]
# Sfxn1 is in cluster [8]
# Nrxn1 is in cluster [1]
# Drd2 is in cluster [9]
# Penk is in cluster [9]
# Sp9 is in cluster [11]
# Gpr52 is in cluster [9]
# Gpr88 is in cluster [9]
#
# Testing for k equals 50...
# [[ 33.           0.45004106]
#  [ 34.           0.38312131]
#  [  9.           0.33491657]
#  [ 30.           0.3070211 ]
#  [ 46.           0.29574863]
#  [ 14.           0.22745538]
#  [ 22.           0.22624804]
#  [ 20.           0.22504758]
#  [  8.           0.21248239]
#  [  2.           0.19043944]
#  [ 18.           0.1709428 ]
#  [ 43.           0.16901412]
#  [ 42.           0.16515722]
#  [ 49.           0.15238326]
#  [ 26.           0.14916918]
#  [  6.           0.13979958]
#  [ 50.           0.13763874]
#  [ 47.           0.13380145]
#  [  1.           0.13253107]
#  [ 28.           0.13209677]]
# Isl1 is in cluster [22]
# Drd1 is in cluster [22]
# Sfxn1 is in cluster [22]
# Nrxn1 is in cluster [29]
# Drd2 is in cluster [13]
# Penk is in cluster [0]
# Sp9 is in cluster [34]
# Gpr52 is in cluster [13]
# Gpr88 is in cluster [13]
#
# Testing for k equals 100...
# [[  14.            0.48309917]
#  [  19.            0.47464591]
#  [  83.            0.44998314]
#  [   4.            0.39059343]
#  [  52.            0.37196879]
#  [ 100.            0.33433652]
#  [  25.            0.29730944]
#  [  43.            0.2900459 ]
#  [  51.            0.26440331]
#  [  38.            0.26373611]
#  [  15.            0.2482553 ]
#  [  48.            0.24681595]
#  [  35.            0.23918328]
#  [  96.            0.23598647]
#  [  46.            0.23344333]
#  [   7.            0.21596129]
#  [  88.            0.21168889]
#  [  11.            0.20266108]
#  [   2.            0.19220625]
#  [  82.            0.18991897]]
# Isl1 is in cluster [57]
# Drd1 is in cluster [57]
# Sfxn1 is in cluster [57]
# Nrxn1 is in cluster [36]
# Drd2 is in cluster [56]
# Penk is in cluster [56]
# Sp9 is in cluster [56]
# Gpr52 is in cluster [56]
# Gpr88 is in cluster [42]
#
# Testing for k equals 200...
# [[ 191.            0.70092239]
#  [  56.            0.62196488]
#  [ 120.            0.53096396]
#  [ 162.            0.50341388]
#  [ 143.            0.46273404]
#  [  52.            0.42897155]
#  [  97.            0.40471927]
#  [ 165.            0.40314076]
#  [ 136.            0.39053433]
#  [ 145.            0.36898119]
#  [ 164.            0.35412584]
#  [ 110.            0.34684687]
#  [   7.            0.32380948]
#  [ 134.            0.32021284]
#  [ 123.            0.30763773]
#  [  63.            0.3062104 ]
#  [  32.            0.30239073]
#  [ 197.            0.29454695]
#  [  31.            0.29425634]
#  [ 106.            0.29175285]]
# Isl1 is in cluster [101]
# Drd1 is in cluster [101]
# Sfxn1 is in cluster [27]
# Nrxn1 is in cluster [124]
# Drd2 is in cluster [133]
# Penk is in cluster [133]
# Sp9 is in cluster [114]
# Gpr52 is in cluster [133]
# Gpr88 is in cluster [62]
#
# Testing for k equals 500...
# [[  4.53000000e+02   7.84363622e-01]
#  [  8.10000000e+01   6.23258296e-01]
#  [  2.70000000e+02   5.23054457e-01]
#  [  5.60000000e+01   5.15819172e-01]
#  [  4.64000000e+02   5.03077873e-01]
#  [  5.40000000e+01   4.97258879e-01]
#  [  1.20000000e+02   4.85000516e-01]
#  [  4.93000000e+02   4.58237640e-01]
#  [  2.03000000e+02   4.42483505e-01]
#  [  4.20000000e+02   4.39677198e-01]
#  [  2.92000000e+02   4.35319269e-01]
#  [  2.99000000e+02   4.35219794e-01]
#  [  7.40000000e+01   4.27799939e-01]
#  [  4.94000000e+02   4.27057413e-01]
#  [  7.00000000e+00   4.19118066e-01]
#  [  4.79000000e+02   4.18547211e-01]
#  [  2.33000000e+02   4.17412883e-01]
#  [  3.52000000e+02   4.16700553e-01]
#  [  1.89000000e+02   3.98257351e-01]
#  [  4.85000000e+02   3.85912211e-01]]
# Isl1 is in cluster [153]
# Drd1 is in cluster [381]
# Sfxn1 is in cluster [278]
# Nrxn1 is in cluster [401]
# Drd2 is in cluster [202]
# Penk is in cluster [202]
# Sp9 is in cluster [131]
# Gpr52 is in cluster [202]
# Gpr88 is in cluster [202]
#
# Testing for k equals 1000...
# -c:27: RuntimeWarning: invalid value encountered in double_scalars
# [[  7.90000000e+02   1.00000000e+00]
#  [  2.53000000e+02   9.86808404e-01]
#  [  5.99000000e+02   9.75707164e-01]
#  [  9.31000000e+02   9.74009384e-01]
#  [  4.09000000e+02   8.96748206e-01]
#  [  3.31000000e+02   8.43233529e-01]
#  [  7.39000000e+02   8.25982694e-01]
#  [  9.44000000e+02   8.22182657e-01]
#  [  5.36000000e+02   7.96946354e-01]
#  [  1.98000000e+02   7.69549950e-01]
#  [  5.10000000e+01   7.58993766e-01]
#  [  1.06000000e+02   7.00465043e-01]
#  [  2.41000000e+02   6.90997895e-01]
#  [  1.82000000e+02   6.81126497e-01]
#  [  9.11000000e+02   6.27925821e-01]
#  [  6.27000000e+02   6.25051858e-01]
#  [  4.25000000e+02   6.14159227e-01]
#  [  3.55000000e+02   5.91202873e-01]
#  [  8.31000000e+02   5.67579920e-01]
#  [  8.50000000e+01   5.62828554e-01]]
# Isl1 is in cluster [535]
# Drd1 is in cluster [535]
# Sfxn1 is in cluster [317]
# Nrxn1 is in cluster [80]
# Drd2 is in cluster [910]
# Penk is in cluster [910]
# Sp9 is in cluster [308]
# Gpr52 is in cluster [910]
# Gpr88 is in cluster [224]
#
# Testing for k equals 2000...
# [[  1.79900000e+03   9.67305721e-01]
#  [  1.26300000e+03   9.45714990e-01]
#  [  1.00000000e+03   9.45403952e-01]
#  [  4.38000000e+02   9.38335387e-01]
#  [  1.44900000e+03   9.35612307e-01]
#  [  1.66000000e+02   9.17519525e-01]
#  [  6.30000000e+02   9.13626619e-01]
#  [  1.82800000e+03   9.09935190e-01]
#  [  6.04000000e+02   9.01422606e-01]
#  [  8.76000000e+02   8.98382699e-01]
#  [  1.01200000e+03   8.90373322e-01]
#  [  1.41100000e+03   8.86102296e-01]
#  [  3.62000000e+02   8.84907375e-01]
#  [  5.53000000e+02   8.78341336e-01]
#  [  1.80100000e+03   8.75166789e-01]
#  [  1.75000000e+02   8.56807508e-01]
#  [  1.41300000e+03   8.37356145e-01]
#  [  2.12000000e+02   8.34520991e-01]
#  [  5.71000000e+02   8.26941568e-01]
#  [  4.50000000e+02   8.26624685e-01]]
# Isl1 is in cluster [1371]
# Drd1 is in cluster [629]
# Sfxn1 is in cluster [1631]
# Nrxn1 is in cluster [1349]
# Drd2 is in cluster [701]
# Penk is in cluster [1412]
# Sp9 is in cluster [158]
# Gpr52 is in cluster [701]
# Gpr88 is in cluster [901]

# %%
# Test for R_abs over all batches
# %matplotlib inline
for batch in np.unique(batches):
    X_batch = X[batches == batch]
    print '-'*80 
    print 'TESTING BATCH ' + str(batch) + ' WHICH HAS ' + str(np.sum(batches == batch)) + ' SAMPLES '
    R_abs = np.abs(np.nan_to_num(np.corrcoef(np.transpose(X_batch))))
    for k in [5,10,20,50,100,200,500,1000,2000]:
        print 'Testing for k equals ' + str(k) + '...'
        labels = jz_bicluster(R_abs,k)
        plot_biclusters(R_abs,labels)
        clust_scores = test_all_clust_scores(R_abs,labels)
        print check_top_sep_scores(clust_scores,20)
        check_d1d2_genes_labels(labels,genes)
# Out:
# --------------------------------------------------------------------------------
# TESTING BATCH 22.0 WHICH HAS 66 SAMPLES
# Testing for k equals 5...
# /usr/lib/python2.7/dist-packages/numpy/lib/function_base.py:1824: RuntimeWarning: invalid value encountered in true_divide
#   return c/sqrt(multiply.outer(d, d))
# /usr/local/lib/python2.7/dist-packages/sklearn/cluster/bicluster.py:37: RuntimeWarning: divide by zero encountered in divide
#   row_diag = np.asarray(1.0 / np.sqrt(X.sum(axis=1))).squeeze()
# /usr/local/lib/python2.7/dist-packages/sklearn/cluster/bicluster.py:38: RuntimeWarning: divide by zero encountered in divide
#   col_diag = np.asarray(1.0 / np.sqrt(X.sum(axis=0))).squeeze()
# /usr/local/lib/python2.7/dist-packages/sklearn/cluster/bicluster.py:47: RuntimeWarning: invalid value encountered in multiply
#   an = row_diag[:, np.newaxis] * X * col_diag
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-62ca1dd4e510> in <module>()
#       8     for k in [5,10,20,50,100,200,500,1000,2000]:
#       9         print 'Testing for k equals ' + str(k) + '...'
# ---> 10         labels = jz_bicluster(R_abs,k)
#      11         plot_biclusters(R_abs,labels)
#      12         clust_scores = test_all_clust_scores(R_abs,labels)
#
# <ipython-input-2-dfdd2685c70e> in jz_bicluster(R, k)
#       7 def jz_bicluster(R,k):
#       8     model = SpectralCoclustering(n_clusters=k, random_state=0)
# ----> 9     model.fit(R)
#      10     return model.row_labels_
#      11
#
# /usr/local/lib/python2.7/dist-packages/sklearn/cluster/bicluster.pyc in fit(self, X)
#     120         X = check_array(X, accept_sparse='csr', dtype=np.float64)
#     121         self._check_parameters()
# --> 122         self._fit(X)
#     123
#     124     def _svd(self, array, n_components, n_discard):
#
# /usr/local/lib/python2.7/dist-packages/sklearn/cluster/bicluster.pyc in _fit(self, X)
#     269         normalized_data, row_diag, col_diag = _scale_normalize(X)
#     270         n_sv = 1 + int(np.ceil(np.log2(self.n_clusters)))
# --> 271         u, v = self._svd(normalized_data, n_sv, n_discard=1)
#     272         z = np.vstack((row_diag[:, np.newaxis] * u,
#     273                        col_diag[:, np.newaxis] * v))
#
# /usr/local/lib/python2.7/dist-packages/sklearn/cluster/bicluster.pyc in _svd(self, array, n_components, n_discard)
#     133             u, _, vt = randomized_svd(array, n_components,
#     134                                       random_state=self.random_state,
# --> 135                                       **kwargs)
#     136
#     137         elif self.svd_method == 'arpack':
#
# /usr/local/lib/python2.7/dist-packages/sklearn/utils/extmath.pyc in randomized_svd(M, n_components, n_oversamples, n_iter, transpose, flip_sign, random_state)
#     294         M = M.T
#     295
# --> 296     Q = randomized_range_finder(M, n_random, n_iter, random_state)
#     297
#     298     # project M to the (k + p) dimensional space using the basis vectors
#
# /usr/local/lib/python2.7/dist-packages/sklearn/utils/extmath.pyc in randomized_range_finder(A, size, n_iter, random_state)
#     227
#     228     # extracting an orthonormal basis of the A range samples
# --> 229     Q, R = linalg.qr(Y, mode='economic')
#     230     return Q
#     231
#
# /usr/lib/python2.7/dist-packages/scipy/linalg/decomp_qr.pyc in qr(a, overwrite_a, lwork, mode, pivoting, check_finite)
#     126
#     127     if check_finite:
# --> 128         a1 = numpy.asarray_chkfinite(a)
#     129     else:
#     130         a1 = numpy.asarray(a)
#
# /usr/lib/python2.7/dist-packages/numpy/lib/function_base.pyc in asarray_chkfinite(a, dtype, order)
#     593     if a.dtype.char in typecodes['AllFloat'] and not np.isfinite(a).all():
#     594         raise ValueError(
# --> 595                 "array must not contain infs or NaNs")
#     596     return a
#     597
#
# ValueError: array must not contain infs or NaNs

# %%
R_abs
# Out:
# array([[ 1.        ,  0.45260931,  0.15390759, ...,  0.3508128 ,
#          0.0116848 ,  0.01611733],
#        [ 0.45260931,  1.        ,  0.05806179, ...,  0.40970153,
#          0.15047816,  0.03927246],
#        [ 0.15390759,  0.05806179,  1.        , ...,  0.12572191,
#          0.02695731,  0.01889025],
#        ...,
#        [ 0.3508128 ,  0.40970153,  0.12572191, ...,  1.        ,
#          0.0597955 ,  0.06038605],
#        [ 0.0116848 ,  0.15047816,  0.02695731, ...,  0.0597955 ,
#          1.        ,  0.01692521],
#        [ 0.01611733,  0.03927246,  0.01889025, ...,  0.06038605,
#          0.01692521,  1.        ]])

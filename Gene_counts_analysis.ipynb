# %%
# Generate correlation matrix
import numpy as np

X = np.loadtxt('/data/jessez/Gene_count_datasets/Datasets/batch_all/X');
gene_names = np.loadtxt('/data/jessez/Gene_count_datasets/Genes/genes.txt',dtype=str)
R = np.corrcoef(np.transpose(X))

# Look at the max correlation for each gene
M = np.shape(R)[0]
max_corr = np.absolute(R-np.identity(M)).max(0)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

plt.figure(figsize=(15,5))
plt.plot(range(0,M),np.sort(max_corr))
plt.show()

# %%
# Only look at genes that have a max correlation of at least a certain threshold
thresh = 0.5
good_genes_ind = np.where(max_corr > thresh)
good_gene_names = gene_names[good_genes_ind]
X_good_genes = np.squeeze(X[:,good_genes_ind])

# Truncate R
a = np.squeeze(R[:,good_genes_ind],axis=1)
R_good_genes = np.squeeze(a[good_genes_ind,:],axis=0)

# See which D1 D2 genes are missing
D1D2_genes = ['Isl1','Drd1','Sfxn1','Nrxn1','Drd1','Penk','Sp9','Gpr52','Gpr88']
print 'D1D2 genes that are missing:'
for gene in D1D2_genes:
    if gene not in good_gene_names:
        print gene
        
M = np.size(good_gene_names)
print str(M) + ' genes remaining.'
# Out:
# D1D2 genes that are missing:
# 3899 genes remaining.

# %%
# Functions for performing PCA, t-SNE, and kmeans

import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn import manifold
from sklearn import cluster

# obtain PCs and plot by batch number
def jz_PCA(X):
    X_zm = X
    X_bar = np.mean(X,axis=0)
    U, s, V = np.linalg.svd(np.dot(X_zm,np.transpose(X_zm)), full_matrices=True)
    return U

# obtain two major directions from t-SNE and plot by batch number
def jz_tSNE(X):
    tsne = manifold.TSNE(n_components=2, random_state=0);
    X_tsne = tsne.fit_transform(X);
    return X_tsne

# obtain labels via kmeans
def jz_kmeans(X,k):
    k_means = cluster.KMeans(n_clusters=k)
    k_means.fit(X)
    labels = k_means.labels_
    return labels

# %%
# PCA on original matrix
# %matplotlib inline
batch_num = np.loadtxt('/data/jessez/Gene_count_datasets/Batch_nums/batch_num_all.txt')
X_pca = jz_PCA(X)

plt.figure(figsize=(15,15))

# plot and color points using batch numbers
batches = np.unique(batch_num)
plt.subplot(2,1,1)
for batch in batches:
    plt.scatter(X_pca[batch_num == batch,0], X_pca[batch_num == batch, 1],c=np.random.rand(3))
    
# plot and color using kmeans labels
pca_labels = jz_kmeans(X_good_genes_pca,2)
plt.subplot(2,1,2)
labels = np.unique(pca_labels)
for label in labels:
    plt.scatter(X_good_genes_pca[pca_labels == label,0],X_good_genes_pca[pca_labels == label,1],c=np.random.rand(3))

plt.show()

# %%
# PCA on matrix with only "good genes" 
# %matplotlib inline
batch_num = np.loadtxt('/data/jessez/Gene_count_datasets/Batch_nums/batch_num_all.txt')
X_good_genes_pca = jz_PCA(X_good_genes)

plt.figure(figsize=(15,15))

# plot and color points using batch numbers
batches = np.unique(batch_num)
plt.subplot(2,1,1)
for batch in batches:
    plt.scatter(X_good_genes_pca[batch_num == batch,0], X_good_genes_pca[batch_num == batch, 1],c=np.random.rand(3))
    
# plot and color using kmeans labels
pca_labels = jz_kmeans(X_good_genes_pca,10)
plt.subplot(2,1,2)
labels = np.unique(pca_labels)
for label in labels:
    plt.scatter(X_good_genes_pca[pca_labels == label,0],X_good_genes_pca[pca_labels == label,1],c=np.random.rand(3))

plt.show()

# %%
# Clustering on genes
gene_labels = jz_kmeans(np.transpose(X_good_genes),2)

# see if d1d2 genes are clustered into the same group
for gene in ['Isl1','Drd1','Sfxn1','Nrxn1','Drd2','Penk','Sp9','Gpr52','Gpr88']:
    ind = np.where(good_gene_names==gene)
    print gene + ' is in cluster ' + str(gene_labels[ind])
# Out:
# Isl1 is in cluster [1]
# Drd1 is in cluster [0]
# Sfxn1 is in cluster [0]
# Nrxn1 is in cluster [0]
# Drd2 is in cluster [1]
# Penk is in cluster [0]
# Sp9 is in cluster [1]
# Gpr52 is in cluster [1]
# Gpr88 is in cluster [0]

# %%
# Look at correlation coefficients of D1D2 genes

for gene1 in ['Isl1','Drd1','Sfxn1','Nrxn1','Drd2','Penk','Sp9','Gpr52','Gpr88']:
    print gene1 + ':'
    for gene2 in ['Isl1','Drd1','Sfxn1','Nrxn1','Drd2','Penk','Sp9','Gpr52','Gpr88']:
        if gene2 != gene1:
            ind1 = np.where(good_gene_names==gene1)
            ind2 = np.where(good_gene_names==gene2)
            print gene1 + ' and ' + gene2 + ' has a correlation of ' + str(R_good_genes[ind1,ind2]) + '.'
    print ' '
# Out:
# Isl1:
# Isl1 and Drd1 has a correlation of [[ 0.69853145]].
# Isl1 and Sfxn1 has a correlation of [[ 0.63479477]].
# Isl1 and Nrxn1 has a correlation of [[ 0.4866611]].
# Isl1 and Drd2 has a correlation of [[-0.47334125]].
# Isl1 and Penk has a correlation of [[-0.57109619]].
# Isl1 and Sp9 has a correlation of [[-0.56781411]].
# Isl1 and Gpr52 has a correlation of [[-0.51801283]].
# Isl1 and Gpr88 has a correlation of [[-0.20690562]].
#
# Drd1:
# Drd1 and Isl1 has a correlation of [[ 0.69853145]].
# Drd1 and Sfxn1 has a correlation of [[ 0.82691806]].
# Drd1 and Nrxn1 has a correlation of [[ 0.54085844]].
# Drd1 and Drd2 has a correlation of [[-0.65020327]].
# Drd1 and Penk has a correlation of [[-0.70323824]].
# Drd1 and Sp9 has a correlation of [[-0.71992715]].
# Drd1 and Gpr52 has a correlation of [[-0.64130504]].
# Drd1 and Gpr88 has a correlation of [[-0.19811676]].
#
# Sfxn1:
# Sfxn1 and Isl1 has a correlation of [[ 0.63479477]].
# Sfxn1 and Drd1 has a correlation of [[ 0.82691806]].
# Sfxn1 and Nrxn1 has a correlation of [[ 0.52152155]].
# Sfxn1 and Drd2 has a correlation of [[-0.52609601]].
# Sfxn1 and Penk has a correlation of [[-0.59338356]].
# Sfxn1 and Sp9 has a correlation of [[-0.67495462]].
# Sfxn1 and Gpr52 has a correlation of [[-0.57828528]].
# Sfxn1 and Gpr88 has a correlation of [[-0.18814454]].
#
# Nrxn1:
# Nrxn1 and Isl1 has a correlation of [[ 0.4866611]].
# Nrxn1 and Drd1 has a correlation of [[ 0.54085844]].
# Nrxn1 and Sfxn1 has a correlation of [[ 0.52152155]].
# Nrxn1 and Drd2 has a correlation of [[-0.33789238]].
# Nrxn1 and Penk has a correlation of [[-0.43264213]].
# Nrxn1 and Sp9 has a correlation of [[-0.40800212]].
# Nrxn1 and Gpr52 has a correlation of [[-0.2965538]].
# Nrxn1 and Gpr88 has a correlation of [[-0.14825847]].
#
# Drd2:
# Drd2 and Isl1 has a correlation of [[-0.47334125]].
# Drd2 and Drd1 has a correlation of [[-0.65020327]].
# Drd2 and Sfxn1 has a correlation of [[-0.52609601]].
# Drd2 and Nrxn1 has a correlation of [[-0.33789238]].
# Drd2 and Penk has a correlation of [[ 0.77393859]].
# Drd2 and Sp9 has a correlation of [[ 0.66525884]].
# Drd2 and Gpr52 has a correlation of [[ 0.73786964]].
# Drd2 and Gpr88 has a correlation of [[ 0.35057248]].
#
# Penk:
# Penk and Isl1 has a correlation of [[-0.57109619]].
# Penk and Drd1 has a correlation of [[-0.70323824]].
# Penk and Sfxn1 has a correlation of [[-0.59338356]].
# Penk and Nrxn1 has a correlation of [[-0.43264213]].
# Penk and Drd2 has a correlation of [[ 0.77393859]].
# Penk and Sp9 has a correlation of [[ 0.69660424]].
# Penk and Gpr52 has a correlation of [[ 0.74428163]].
# Penk and Gpr88 has a correlation of [[ 0.40587861]].
#
# Sp9:
# Sp9 and Isl1 has a correlation of [[-0.56781411]].
# Sp9 and Drd1 has a correlation of [[-0.71992715]].
# Sp9 and Sfxn1 has a correlation of [[-0.67495462]].
# Sp9 and Nrxn1 has a correlation of [[-0.40800212]].
# Sp9 and Drd2 has a correlation of [[ 0.66525884]].
# Sp9 and Penk has a correlation of [[ 0.69660424]].
# Sp9 and Gpr52 has a correlation of [[ 0.69373441]].
# Sp9 and Gpr88 has a correlation of [[ 0.37590417]].
#
# Gpr52:
# Gpr52 and Isl1 has a correlation of [[-0.51801283]].
# Gpr52 and Drd1 has a correlation of [[-0.64130504]].
# Gpr52 and Sfxn1 has a correlation of [[-0.57828528]].
# Gpr52 and Nrxn1 has a correlation of [[-0.2965538]].
# Gpr52 and Drd2 has a correlation of [[ 0.73786964]].
# Gpr52 and Penk has a correlation of [[ 0.74428163]].
# Gpr52 and Sp9 has a correlation of [[ 0.69373441]].
# Gpr52 and Gpr88 has a correlation of [[ 0.43520564]].
#
# Gpr88:
# Gpr88 and Isl1 has a correlation of [[-0.20690562]].
# Gpr88 and Drd1 has a correlation of [[-0.19811676]].
# Gpr88 and Sfxn1 has a correlation of [[-0.18814454]].
# Gpr88 and Nrxn1 has a correlation of [[-0.14825847]].
# Gpr88 and Drd2 has a correlation of [[ 0.35057248]].
# Gpr88 and Penk has a correlation of [[ 0.40587861]].
# Gpr88 and Sp9 has a correlation of [[ 0.37590417]].
# Gpr88 and Gpr52 has a correlation of [[ 0.43520564]].

# %%
# Parallelize matrix multiplcation
from IPython.parallel import Client
c = Client()
dview = c[:] # use all engines
def pdot(v, A, B):
    v['B'] = B
    v.scatter('A', A)
    v.execute('C=A.dot(B)')
    return v.gather('C',block=True)

# %%
# Spectral Analysis of R matrix
R = R_good_genes

# Create adjacency matrix from R
A = np.zeros(np.shape(R))
A[R > 0] = 1
A[R <= 0] = 0
for i in range(M):
    A[i,i] = 0;
    
# Create degree matrix from A
D = np.diag(np.sum(A,axis=0))

# Create Laplacian matrix
L = D - A

# Normalize the Laplacian
D_norm = np.diag(np.power(np.sum(A,axis=0),-0.5))
L1 = pdot(dview,D_norm,L)
L_norm = pdot(dview,L1,D_norm)

print L_norm

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import scipy.linalg

# Look at top k eigenvalues and eigenvectors
k = 50
w,v = scipy.linalg.eigh(L_norm,eigvals=(0,k-1))
plt.figure(figsize=(15,15))
plt.stem(w)
plt.show()

# %%
# Clustering on genes
gene_labels = jz_kmeans(v[:,0:2],2)

# see if d1d2 genes are clustered into the same group
for gene in ['Isl1','Drd1','Sfxn1','Nrxn1','Drd2','Penk','Sp9','Gpr52','Gpr88']:
    ind = np.where(good_gene_names==gene)
    print gene + ' is in cluster ' + str(gene_labels[ind])
# Out:
# Isl1 is in cluster [0]
# Drd1 is in cluster [0]
# Sfxn1 is in cluster [1]
# Nrxn1 is in cluster [0]
# Drd2 is in cluster [1]
# Penk is in cluster [1]
# Sp9 is in cluster [0]
# Gpr52 is in cluster [0]
# Gpr88 is in cluster [0]

# %%
# How well do we do with just the d1d2 genes?
test_names = ['Isl1','Drd1','Sfxn1','Nrxn1','Drd2','Penk','Sp9','Gpr52','Gpr88']

ind = np.zeros(np.size(gene_names))
for gene in test_names:
    ind[np.where(gene_names == gene)] = 1
ind = np.where(ind)

# Truncate R
a = np.squeeze(R[:,ind],axis=1)
R_test = np.squeeze(a[ind,:],axis=0)

print np.shape(R_test)
# Out:
# (9, 9)

# %%
# Biclustering on test data

from sklearn.cluster.bicluster import SpectralCoclustering
model = SpectralCoclustering(n_clusters=2, random_state=0)
model.fit(R_test)

fit_data = R_test[np.argsort(model.row_labels_)]
fit_data = fit_data[:, np.argsort(model.column_labels_)]

plt.matshow(fit_data, cmap=plt.cm.Blues)
plt.title("After biclustering; rearranged to show biclusters")

plt.show()

# %%
# Look at the genes associated with each cluster

for i in range(9):
    if model.row_labels_[i] == 1:
        print gene_names[ind[0][i]]
# Out:
# Drd1
# Isl1
# Nrxn1
# Sfxn1

# %%
# Perform the biclustering on R

# %matplotlib inline
from sklearn.cluster.bicluster import SpectralCoclustering

# # Threshold the matrix
# A = np.zeros(np.shape(R))
# A[R > 0] = 1
# A[R <= 0] = 0

A = R

# Try a bunch of different clusters.. 
for k in range(2,20):
    model = SpectralCoclustering(n_clusters=k, random_state=0)
    model.fit(A)

    fit_data = A[np.argsort(model.row_labels_)]
    fit_data = fit_data[:, np.argsort(model.column_labels_)]
    
#     plt.matshow(fit_data, cmap=plt.cm.Blues)
#     plt.title("After biclustering; rearranged to show biclusters")
#     plt.show()

    print k
    # see if d1d2 genes are clustered into the same group
    for gene in ['Isl1','Drd1','Sfxn1','Nrxn1','Drd2','Penk','Sp9','Gpr52','Gpr88']:
        print model.row_labels_[np.where(gene_names == gene)]
    print ' '
# Out:
# 2
# [1]
# [1]
# [0]
# [1]
# [0]
# [0]
# [1]
# [1]
# [1]
#
# 3
# [0]
# [2]
# [2]
# [1]
# [0]
# [0]
# [0]
# [0]
# [0]
#
# 4
# [2]
# [2]
# [2]
# [3]
# [0]
# [0]
# [0]
# [0]
# [0]
#
# 5
# [4]
# [4]
# [4]
# [4]
# [0]
# [0]
# [0]
# [0]
# [0]
#
# 6
# [3]
# [3]
# [3]
# [3]
# [2]
# [2]
# [2]
# [2]
# [2]
#
# 7
# [4]
# [4]
# [4]
# [4]
# [6]
# [6]
# [6]
# [6]
# [6]
#
# 8
# [5]
# [5]
# [5]
# [5]
# [6]
# [6]
# [6]
# [6]
# [6]
#
# 9
# [5]
# [5]
# [5]
# [5]
# [1]
# [0]
# [0]
# [0]
# [0]
#
# 10
# [7]
# [7]
# [7]
# [4]
# [0]
# [6]
# [6]
# [6]
# [6]
#
# 11
# [7]
# [7]
# [7]
# [6]
# [5]
# [5]
# [5]
# [5]
# [9]
#
# 12
# [7]
# [7]
# [7]
# [7]
# [0]
# [0]
# [0]
# [0]
# [6]
#
# 13
# [4]
# [4]
# [4]
# [4]
# [0]
# [0]
# [0]
# [0]
# [6]
#
# 14
# [11]
# [1]
# [11]
# [13]
# [12]
# [12]
# [12]
# [12]
# [10]
#
# 15
# [5]
# [5]
# [5]
# [4]
# [14]
# [14]
# [14]
# [14]
# [0]
#
# 16
# [11]
# [2]
# [11]
# [11]
# [15]
# [15]
# [15]
# [15]
# [3]
#
# 17
# [6]
# [7]
# [7]
# [14]
# [3]
# [11]
# [11]
# [3]
# [3]
#
# 18
# [17]
# [0]
# [0]
# [14]
# [11]
# [11]
# [10]
# [11]
# [11]
#
# 19
# [15]
# [9]
# [9]
# [0]
# [6]
# [6]
# [6]
# [10]
# [10]

# %%
# Perform the biclustering on R

# %matplotlib inline
from sklearn.cluster.bicluster import SpectralCoclustering

k = 200
model = SpectralCoclustering(n_clusters=k, random_state=0)
model.fit(R)

fit_data = R[np.argsort(model.row_labels_)]
fit_data = fit_data[:, np.argsort(model.column_labels_)]

plt.matshow(fit_data, cmap=plt.cm.Blues)
plt.title("After biclustering; rearranged to show biclusters")
plt.show()

print str(k) + ' total clusters'
# see if d1d2 genes are clustered into the same group
for gene in ['Isl1','Drd1','Sfxn1','Nrxn1','Drd2','Penk','Sp9','Gpr52','Gpr88']:
    print model.row_labels_[np.where(gene_names == gene)]
print ' '

d1_label = model.row_labels_[np.where(gene_names == 'Drd1')]
d2_label = model.row_labels_[np.where(gene_names == 'Drd2')]
print np.sum(model.row_labels_ == d1_label)
print np.sum(model.row_labels_ == d2_label)
print ' '

# save relevant genes
save_genes = np.zeros(np.size(gene_names))
for i in range(np.size(gene_names)):
    if model.row_labels_[i] == d1_label or model.row_labels_[i] == d2_label:
        save_genes[i] = 1
# np.savetxt('/home/jessez/genes_biclust_corr_' + str(k) + '_clusts.txt',gene_names[np.where(save_genes)],delimiter='\t',fmt="%s")
# Out:
# 200 total clusters
# [120]
# [120]
# [120]
# [32]
# [99]
# [99]
# [99]
# [99]
# [166]
#
# 11
# 9

# %%
# Only plot clusters containing the D1 D2 genes

# %matplotlib inline

# Truncate R
a = np.squeeze(R[:,np.where(save_genes)],axis=1)
R_test = np.squeeze(a[np.where(save_genes),:],axis=0)

# Bicluster
d1d2_model = SpectralCoclustering(n_clusters=2, random_state=0)
d1d2_model.fit(R_test)

fit_data = R_test[np.argsort(d1d2_model.row_labels_)]
fit_data = fit_data[:, np.argsort(d1d2_model.column_labels_)]

plt.matshow(fit_data, cmap=plt.cm.Blues)
plt.title("After biclustering; rearranged to show biclusters")
plt.show()

# %%
# Define a cluster separation metric: how well two clusters are separated

from sklearn.cluster.bicluster import SpectralCoclustering

def jz_bicluster(R,k):
    model = SpectralCoclustering(n_clusters=k, random_state=0)
    model.fit(R)
    return model.row_labels_
    
def sep_metric(c1,c2,R,labels):
    # number of each label
    n1 = float(np.sum(labels == c1))
    n2 = float(np.sum(labels == c2))
    sep_score = 0
    
    # Only consider blocks that are close enough in size (e.g. one is at least half the size of the other)
    if np.min([n1/n2,n2/n1]) > 0.5:
        
        # Sum up correlations
        s1 = np.sum(R[labels == c1,:][:,labels == c1])
        s2 = np.sum(R[labels == c2,:][:,labels == c2])
        s3 = np.sum(R[labels == c1,:][:,labels == c2])
    
        # Only consider cases where main blocks all have mean > 0 and side blocks have mean < 0
#         if s1 > 0 and s2 > 0 and s3 <= 0:
            
        # Use all three sums to compute score
        sep_score = (s1+s2)/(n1**2+n2**2) - 2*s3/(n1*n2)
    return sep_score


def test_all_clust_sep_metric(R,labels):
    max_label = np.max(labels)+1
    save_sep = 0
    save_c1 = -1
    save_c2 = -1
    # for every two sets of clusters
    for i in range(max_label-1):
        for j in range(i+1,max_label):
            sep_score = sep_metric(i,j,R,labels)
            if sep_score > save_sep:
                save_sep = sep_score
                save_c1 = i
                save_c2 = j
                print str(i) + ' ' + str(j) + ' ' + str(sep_score)
    return np.array([save_c1,save_c2,save_sep])


def generate_bicluster_plot(c1,c2,R,labels):
    
    # Truncate R
    ind = (labels == c1) + (labels == c2)
    R_test = R[ind,:][:,ind]
    
    # Bicluster
    temp_model = SpectralCoclustering(n_clusters=2, random_state=0)
    temp_model.fit(R_test)
    
    fit_data = R_test[np.argsort(temp_model.row_labels_)]
    fit_data = fit_data[:, np.argsort(temp_model.column_labels_)]
    
    plt.figure()
    plt.matshow(fit_data, cmap=plt.cm.Blues)
    plt.title("After biclustering; rearranged to show biclusters")
    plt.show()

# %%
print sep_metric(99,120,R,labels)
generate_bicluster_plot(99,129,R,labels)
# Out:
# 1.52075477016

# %%
sep_metric(R,model.row_labels_)
# Out:
# 0 121 0.293195685333
# 0 178 0.280857834133
# 9 20 0.252684733115
# 9 33 0.207303418786
# 9 59 0.190343647014
# 9 136 0.225981216993
# 9 166 0.43171061483
# 9 170 0.198472159385
# 9 188 0.35803314695
# 20 71 0.408758430247
# 20 108 0.365182080954
# 20 175 0.269638611468
# 23 71 0.163401160373
# 31 108 0.51854396865
# 31 120 1.00021106523
# 33 71 0.322947881367
# 33 108 0.368362046768
# 44 71 0.249993089794
# 44 108 0.233735890583
# 51 71 0.27718172573
# 59 71 0.251908167451
# 65 172 0.398895428135
# 71 79 0.195815112373
# 71 87 0.519104224058
# 71 126 0.289093086417
# 71 127 0.231620615804
# 71 136 0.372566127979
# 71 141 0.282192148027
# 71 147 0.241652594685
# 71 166 0.5518350765
# 71 168 0.268570437638
# 71 170 0.29538332142
# 71 180 0.217718691405
# 71 188 0.568204365548
# 87 172 0.314707273248
# 99 120 1.52075477016
# 100 166 0.296860696574
# 100 188 0.247050227716
# 106 121 0.392306785556
# 106 178 0.406227743849
# 108 127 0.151376758213
# 108 136 0.285723045104
# 108 141 0.222383324336
# 108 170 0.273032221498
# 108 174 0.486748468806
# 108 188 0.521234744628
# 120 174 0.691129196057
# 124 127 0.170520995638
# 124 180 0.166665116579
# 127 175 0.18121821655
# 130 169 0.498338653042
# 130 172 0.491683448308
# 157 172 0.133954816678
# 166 175 0.362671926972
# 169 178 0.156066494566
# 169 181 0.143353163383
# 170 175 0.238709974184
# 172 178 0.170622458407
# 175 188 0.371219612156
# array([  99.        ,  120.        ,    1.52075477])

# %%
# Test various values of k, and see how well they do at selecting out biclusters that correspond to d1 and d2

for k in [5,10,20,50,100,200,500,1000,2000]:
    print 'Testing for k equals ' + str(k) + '...'
    labels = jz_bicluster(R,k)
    best_clust = test_all_clust_sep_metric(R,labels)
    print 'The best clusters were: ' + str(int(best_clust[0])) + ' and ' + str(int(best_clust[1]))
    print 'Drd1 is in cluster ' + str(labels[np.where(gene_names == 'Drd1')]) 
    print 'Drd2 is in cluster ' + str(labels[np.where(gene_names == 'Drd2')])
    generate_bicluster_plot(best_clust[0],best_clust[1],R,labels)
    print ''
# Out:
# Testing for k equals 5...
# 0 3 0.00789312107336
# The best clusters were: 0 and 3
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-267-6c89bc3af657> in <module>()
#       8     print 'Drd1 is in cluster ' + str(labels[np.where(gene_names == 'Drd1')])
#       9     print 'Drd2 is in cluster ' + str(labels[np.where(gene_names == 'Drd2')])
# ---> 10     generate_bicluster_plot(best_clust[0],best_clust[1],R,labels)
#      11     print ''
#      12
#
# <ipython-input-264-954a742be913> in generate_bicluster_plot(c1, c2, R, labels)
#      55     # Bicluster
#      56     temp_model = SpectralCoclustering(n_clusters=2, random_state=0)
# ---> 57     temp_model.fit(R_test)
#      58
#      59     fit_data = R_test[np.argsort(temp_model.row_labels_)]
#
# /usr/local/lib/python2.7/dist-packages/sklearn/cluster/bicluster.pyc in fit(self, X)
#     118
#     119         """
# --> 120         X = check_array(X, accept_sparse='csr', dtype=np.float64)
#     121         self._check_parameters()
#     122         self._fit(X)
#
# /usr/local/lib/python2.7/dist-packages/sklearn/utils/validation.pyc in check_array(array, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features)
#     358             raise ValueError("Found array with %d sample(s) (shape=%s) while a"
#     359                              " minimum of %d is required."
# --> 360                              % (n_samples, shape_repr, ensure_min_samples))
#     361
#     362     if ensure_min_features > 0 and array.ndim == 2:
#
# ValueError: Found array with 0 sample(s) (shape=(0, 0)) while a minimum of 1 is required.
# Drd1 is in cluster [4]
# Drd2 is in cluster [0]

# %%
generate_bicluster_plot(best_clust[0],best_clust[1],R,labels)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-275-297952d703da> in <module>()
# ----> 1 generate_bicluster_plot(best_clust[0],best_clust[1],R,labels)
#
# <ipython-input-274-7a40b717635d> in generate_bicluster_plot(c1, c2, R, labels)
#      56     # Bicluster
#      57     temp_model = SpectralCoclustering(n_clusters=2, random_state=0)
# ---> 58     temp_model.fit(R_test)
#      59
#      60     fit_data = R_test[np.argsort(temp_model.row_labels_)]
#
# /usr/local/lib/python2.7/dist-packages/sklearn/cluster/bicluster.pyc in fit(self, X)
#     118
#     119         """
# --> 120         X = check_array(X, accept_sparse='csr', dtype=np.float64)
#     121         self._check_parameters()
#     122         self._fit(X)
#
# /usr/local/lib/python2.7/dist-packages/sklearn/utils/validation.pyc in check_array(array, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features)
#     358             raise ValueError("Found array with %d sample(s) (shape=%s) while a"
#     359                              " minimum of %d is required."
# --> 360                              % (n_samples, shape_repr, ensure_min_samples))
#     361
#     362     if ensure_min_features > 0 and array.ndim == 2:
#
# ValueError: Found array with 0 sample(s) (shape=(0, 0)) while a minimum of 1 is required.
# [False False False ..., False False False]
